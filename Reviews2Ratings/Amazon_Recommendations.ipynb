# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/data/amazon_review_small.txt', header=None)

# %%
df
# Out:
#         0                                               1  \
# 0       1                                 mens ultrasheer
# 1       4                         Surprisingly delightful
# 2       2                    Works, but not as advertised
# 3       2                                         Oh dear
# 4       2                                 Incorrect disc!
# ...    ..                                             ...
# 649995  5                                    Pretty Cool!
# 649996  5                                        great cd
# 649997  2  An interesting look into Boston's comedy clubs
# 649998  5                      Du vol...pour les cowboys!
# 649999  4      A Companion Read To GUNS, GERMS, AND STEEL
#
#                                                         2
# 0       This model may be ok for sedentary types, but ...
# 1       This is a fast read filled with unexpected hum...
# 2       I bought one of these chargers..the instructio...
# ...

# %%
# Downsides of asking chatGPT to do it for you
# 1. Cost - embedding are dirt cheap
# 2. Inaccurate
# 3. Data Privacy
# 4. Time

# %%
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def embed(input):
  return model(input)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
df
# Out:
#         0                                               1  \
# 0       1                                 mens ultrasheer
# 1       4                         Surprisingly delightful
# 2       2                    Works, but not as advertised
# 3       2                                         Oh dear
# 4       2                                 Incorrect disc!
# ...    ..                                             ...
# 649995  5                                    Pretty Cool!
# 649996  5                                        great cd
# 649997  2  An interesting look into Boston's comedy clubs
# 649998  5                      Du vol...pour les cowboys!
# 649999  4      A Companion Read To GUNS, GERMS, AND STEEL
#
#                                                         2
# 0       This model may be ok for sedentary types, but ...
# 1       This is a fast read filled with unexpected hum...
# 2       I bought one of these chargers..the instructio...
# ...

# %%
df_test = df.sample(frac=0.2)

# %%
df_train = df.drop(df_test.index)

# %%
df_test.shape
# Out:
# (130000, 3)

# %%
df_train.shape
# Out:
# (520000, 3)

# %%
ls /content/drive/MyDrive/data
# Out:
# amazon_review_small.txt  df_test.csv

# %%
df_test.to_csv("/content/drive/MyDrive/data/df_test.csv")

# %%
df_train.to_csv("/content/drive/MyDrive/data/df_train.csv")

# %%
df_train = pd.read_csv('/content/drive/MyDrive/data/df_train.csv')

# %%
df_train
# Out:
#         Unnamed: 0  0                                               1  \
# 0                1  4                         Surprisingly delightful
# 1                2  2                    Works, but not as advertised
# 2                3  2                                         Oh dear
# 3                4  2                                 Incorrect disc!
# 4                8  5               A Cookbook Every Baker Should Own
# ...            ... ..                                             ...
# 519995      649995  5                                    Pretty Cool!
# 519996      649996  5                                        great cd
# 519997      649997  2  An interesting look into Boston's comedy clubs
# 519998      649998  5                      Du vol...pour les cowboys!
# 519999      649999  4      A Companion Read To GUNS, GERMS, AND STEEL
#
#                                                         2
# 0       This is a fast read filled with unexpected hum...
# ...

# %%
train_txt_1 = df_train.loc[:10000]["2"]

# %%
y_1 = df_train.loc[:10000]["0"]

# %%
y_1 = y_1.to_numpy()

# %%
train_embed_1 = embed(train_txt_1).numpy()

# %%
# !mkdir /content/drive/MyDrive/data/train

# %%
np.save("/content/drive/MyDrive/data/train/train_embed_1.npy", train_embed_1)

# %%
np.save("/content/drive/MyDrive/data/train/y_1.npy", y_1)

# %%
# !ls /content/drive/MyDrive/data/train
# Out:
# train_embed_1.npy

# %%
# !ls
# Out:
# drive  embeding_batch.np.npy  sample_data

# %%
train_embed_1 = np.load("/content/drive/MyDrive/data/train/train_embed_1.npy")

# %%
y_1 = np.load("/content/drive/MyDrive/data/train/y_1.npy")

# %%
train_embed_1.shape, y_1.shape
# Out:
# ((10001, 512), (10001,))

# %%
import tensorflow as tf
import keras
from keras import layers

# %%
model = keras.Sequential(
    [
        layers.Dense(30,activation="relu", name="layer1"),
        layers.Dense(10, activation="relu", name="layer2"),
        layers.Dense(1, name="layer3"),
    ]
)

# %%
model.compile(optimizer='sgd', loss='mse')

# %%
model.fit?

# %%
model.fit(train_embed_1, y_1, epochs=100)
# Out:
# Epoch 1/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9636
# Epoch 2/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2386
# Epoch 3/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1358
# Epoch 4/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1022
# Epoch 5/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0866
# Epoch 6/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0746
# Epoch 7/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0668
# Epoch 8/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0588
# Epoch 9/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0529
# Epoch 10/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0476
# Epoch 11/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0394
# Epoch 12/100
# ...

# %%
# Regression task to predict rating from review

# INput? Text - 1 hot encoding, tfidf, word2vec, embeddings
# Use the OpenAI embeddings or USE embeddings.
# Convert Text -> number, save the resut in a file. X and y

# %%
# X - 512 numbers, y - 0 to 5

# %%
# Split X and y to train and test. 80 % - 20%

# %%
# Compare R2
# 1. Linear regression
# 2. SVM
# 3. Random Forrest
# ...

# %%
# Build a sequential neural network
model = tf.keras.Sequential([
            tf.keras.layers.Dense(4 * n_embd), # 4*n_embd
            tf.keras.layers.ReLU(),
            tf.keras.layers.Dense(n_embd), # n_embed
            tf.keras.layers.Dropout(dropout),
        ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-650379cbe637> in <cell line: 2>()
#       1 # Build a sequential neural network
# ----> 2 model = tf.keras.Sequential([
#       3             tf.keras.layers.Dense(4 * n_embd), # 4*n_embd
#       4             tf.keras.layers.ReLU(),
#       5             tf.keras.layers.Dense(n_embd), # n_embed
#
# NameError: name 'tf' is not defined
